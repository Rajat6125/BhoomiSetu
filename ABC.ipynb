# %%
from supabase import create_client
import pandas as pd

url = "https://zrupxlfgyxhsunkqdddx.supabase.co"
key = "sb_publishable_4HJp-q9koA_-K-FONjgtQg_2eTIwsB4"

supabase = create_client(url, key)

response1 = supabase.table("crop_recommendation").select("*").execute()
df1 = pd.DataFrame(response1.data)

response2 = supabase.table("crop_yield").select("*").execute()
df2 = pd.DataFrame(response2.data)

# %%
df1.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df2.columns
# Out:
# Index(['Dist Code', 'Year', 'State Code', 'State Name', 'Dist Name', 'Crop',
#        'Area_ha', 'Yield_kg_per_ha', 'Soil_Test_N_ppm', 'Soil_Test_P_ppm',
#        'Soil_Test_K_ppm', 'Soil_Nutrient_Index', 'Total_N_kg', 'Total_P_kg',
#        'Total_K_kg', 'Temperature_C', 'Humidity_%', 'pH', 'Rainfall_mm',
#        'Wind_Speed_m_s', 'Solar_Radiation_MJ_m2_day'],
#       dtype='object')
